# %% [markdown]
# <a href="https://colab.research.google.com/github/jakewalter/ok_injection_earthquakes/blob/main/downloadinjection1012a_ogs_catalog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import fiona
import numpy as np
import scipy.io as sio
import matplotlib.path as mpltPath




import datetime



tab1=pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/all-2006-2010-uic-1012a.xls')



#tab1 = readtable('Dly1012d_2016.xlsx');
tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2011-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
#yearokla = tab1.YEAR
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2011
injdat = pd.DataFrame()
form = tab1.FormationName

timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')

for t in np.arange(0,12):
    # #injdat1 = pd.concat([apis, (timestep1[t]), tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    # injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    # injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    # injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    # injdat = pd.concat([injdat, injdat1], ignore_index=True)
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)



tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2012-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.FormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2012
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)



tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2013-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.FormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2013
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)


tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2014-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.FormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2014
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)


tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2015-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.FormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2015
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)


tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2016-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.FormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2016
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)

tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2017-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.FormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2017
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)


tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2018-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.FormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2018
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)


tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2019-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.FormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2019
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)



tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2020-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.FormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2020
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)

tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2021-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.PermitFormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2021
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)

tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2022-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.PermitFormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2022
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)


tab1 = pd.read_excel('https://oklahoma.gov/content/dam/ok/en/occ/documents/og/ogdatafiles/2023-uic-injection-volumes.xlsx')
#oklat = year(tab1.Report_Date[0])+ (datenum(tab1.Report_Date)-datenum(year(tab1.Report_Date[0],1,1,0,0,0)+1)./366;
apis = tab1.API
#vol_bpd = tab1.Volume_BPD
#pressure = tab1.Pressure_PSI
latokla = tab1.LAT
lonokla = tab1.LON
form = tab1.PermitFormationName
injtop = tab1.InjTopDepth
injbot = tab1.InjBotDepth
year = 2023
timestep1 = pd.date_range(start='1/1/'+str(year), end='12/31/'+str(year), freq='M')
for t in np.arange(0,12):
    injdat1 = pd.concat([apis, tab1.iloc[:,32+t*2], tab1.iloc[:,33+t*2], latokla, lonokla, form, injtop, injbot], axis=1)
    injdat1 = injdat1.assign(Dec_Year=timestep1[t])
    injdat1.columns = ['API', 'Volume', 'Pressure', 'Latitude', 'Longitude', 'Formation', 'Inj_Top', 'Inj_Bot', 'Dec_Year']
    injdat = pd.concat([injdat, injdat1], ignore_index=True)


wellapi1 = pd.concat([injdat['API'], injdat['Latitude'], injdat['Longitude']], axis=1);
wellapi = wellapi1.drop_duplicates('API')
wellapi = wellapi.reset_index(drop=True)

#


#for idx, val in wellapi['API']:
#    temp = find(wellapi[idx] == wellapi1(:,1));
#    wellapis(i,1:3) = [wellapi(i) wellapi1(temp(1),2:3)];

welldat = wellapi;

#


#s = cell(length(wellapi),4);
#s(1,1:5) = {1 1 1 1 1};
mydate = datetime.datetime.now()
current = datetime.datetime(mydate.year, mydate.month, 1)
next_month = datetime.datetime(mydate.year + int(mydate.month / 12), ((mydate.month % 12) + 1), 1)
enddate = str(next_month.month)+'/1/'+str(next_month.year)
timestepa = pd.date_range(start='1/1/2009', end=enddate, freq='M')
s = pd.DataFrame()
for g, val in enumerate(welldat['API']):
    indxw = injdat['API'].loc[lambda x: x==welldat['API'].iloc[g]].index
    if indxw is not None:

        temp2 = injdat.loc[indxw,:]


        temp3 = []
        for f in np.arange(1,len(timestepa)):
            #print(timestepa[f])
            liqpa = np.nansum(temp2[(temp2['Dec_Year']==timestepa[f-1])]['Volume'])
            temp3.append({'time':timestepa[f],'barrels':liqpa})
        temp3 = pd.DataFrame(temp3)
            #sums_up_alla(f,1:2) = [timestepa(f) liqpa]
        if temp2 is not None:
            df2 = pd.DataFrame({'API':welldat.loc[g,'API'], 'Latitude':welldat.loc[g,'Latitude'], 'Longitude':welldat.loc[g,'Longitude'],'temp2':[temp2],'temp3':[temp3]}, index=[g])
            #s = s.append(df2)
            s = pd.concat([s,df2])



timestep = pd.date_range(start='1/1/2010', end=enddate, freq='M')
sums_up_all = pd.DataFrame()
for f in np.arange(1,len(timestep)):
    liqp = np.nansum(injdat[(injdat['Dec_Year']==timestep[f])]['Volume'])
    dfall = pd.DataFrame({'Date':timestep[f],'Volume':liqp},index=[f])
    #sums_up_all = sums_up_all.append(dfall)
    sums_up_all = pd.concat([sums_up_all,dfall])





# extent = x_min, x_max, y_min, y_max = [bhta['Longitude'].min(), bhta['Longitude'].max(),
#                                        bhta['Latitude'].min(), bhta['Latitude'].max()]
# grid_x, grid_y = np.mgrid[x_min:x_max:.1, y_min:y_max:.1]
# rbfi = Rbf(bhta['Longitude'], bhta['Latitude'], bhta[0], function='linear', smooth=1)
# di = rbfi(grid_x, grid_y)

# # Make the plot.
# plt.figure(figsize=(10, 10))
# plt.imshow(di.T, origin="lower", extent=extent,vmin=20, vmax=40)
# cb = plt.scatter(bhta['Longitude'], bhta['Latitude'], s=5, c=bhta[0], edgecolor='#ffffff66',vmin=20, vmax=40)
# plt.colorbar(cb, shrink=0.67)
# #plt.colorbar()
# plt.show()




injdat.to_hdf('injection_data_allformations.h5', key='injdat', mode='w')



def by_formation(injdat,formation=None):
    injdat1 = injdat[injdat['Formation'].str.contains(formation, na=False, case=False)]
    timestep = pd.date_range(start='1/1/2010', end=enddate, freq='M')
    sums_up_all = pd.DataFrame()
    for f in np.arange(1,len(timestep)):
        liqp = np.nansum(injdat1[(injdat1['Dec_Year']==timestep[f])]['Volume'])
        dfall = pd.DataFrame({'Date':timestep[f],'Volume':liqp},index=[f])
        sums_up_all = pd.concat([sums_up_all,dfall])
    return sums_up_all

# %%
plt.figure()
#ordovician, middle or upper devoninan
plt.step(sums_up_all['Date'],sums_up_all['Volume']/1e6, color='k',label='All injection statewide')
arb_sum = by_formation(injdat,'arbuckle')
plt.step(arb_sum['Date'],arb_sum['Volume']/1e6, color='tab:blue',label='Arbuckle')
dev_ord_sum = by_formation(injdat,'simpson|cincinnatian|hunton|oil creek|mclish|wilcox|bromide|viola|sylvan|chmneyhill|henryhouse|bois|frisco|misener|devonian')
plt.step(dev_ord_sum['Date'],dev_ord_sum['Volume']/1e6, color='tab:orange',label='Dev. to Mid Ord.')
woodford_sum= by_formation(injdat,'woodford')
plt.step(woodford_sum['Date'],woodford_sum['Volume']/1e6, color='tab:green',label='Woodford')
miss_sum= by_formation(injdat,'osage|meramac|chester|kinder|sycamore|mayes|louis|miss|miss lime|caney|manning|mississippian')
plt.step(miss_sum['Date'],miss_sum['Volume']/1e6, color='tab:red',label='Mississippian')
atokan_sum = by_formation(injdat,'wamsley|atoka|morrow|springer|cromwell|dutcher|gilcrease')
plt.step(atokan_sum['Date'],atokan_sum['Volume']/1e6, color='tab:purple',label='Atokan-Morrowan')
desmoines_sum = by_formation(injdat,'hartshorne|bartlesville|burbank|red fork|skinner|oswego|deese|krebs')
plt.step(desmoines_sum['Date'],desmoines_sum['Volume']/1e6, color='tab:brown',label='Desmoinesian')
missouri_sum = by_formation(injdat,'hoxbar|lansing|cottage|kansas|hogshooter|layton|cleveland')
plt.step(missouri_sum['Date'],missouri_sum['Volume']/1e6, color='tab:pink',label='Missourian')
virgil_sum = by_formation(injdat,'douglas|shawnee|wabaunsee|cisco|pawhuska|endicott|tonkawa')
plt.step(virgil_sum['Date'],virgil_sum['Volume']/1e6, color='tab:gray',label='Virgilian')
permian_sum = by_formation(injdat,'permian|admire|council|chase|belveal|pontotoc|dolomite|garber')
plt.step(permian_sum['Date'],permian_sum['Volume']/1e6, color='tab:olive',label='Permian')
plt.legend()
plt.ylabel('Class II monthly injection volume (Million bbl/mo)')


#### Load earthquakes



polygon = [[37.0001,-103.0027],
[36.9989,-94.6180],
[36.4994,-94.6179],
[35.3925,-94.4307],
[33.6379,-94.4858],
[33.8399,-94.9510],
[33.9053,-95.1830],
[33.9231,-95.4328],
[33.8756,-95.8433],
[33.8220,-96.3668],
[33.8161,-96.8902],
[33.8756,-97.5327],
[33.9648,-97.9669],
[34.1076,-98.4666],
[34.2801,-99.1507],
[34.4109,-99.5433],
[34.5606,-100.0008],
[36.4997,-100.0008],
[36.5004,-103.0029],
[37.0001,-103.0027]]

#### earthquake
catdf = pd.read_csv('http://wichita.ogs.ou.edu/eq/catalog/complete/complete.csv')
#points = [[lat,lon]
#path = mpltPath.Path(polygon)
#inside2 = path.contains_points(points)

eqtempin = catdf[['latitude','longitude']].to_numpy()
eqpath = mpltPath.Path(polygon)
insidestate = eqpath.contains_points(eqtempin)


catdf = catdf[insidestate]
catdf = catdf.reset_index(drop=True)



catdf['origintime'] = pd.to_datetime(catdf['origintime'])
catdf['magnitude'] = catdf['magnitude'].astype(str).replace("None", "0").astype(float)
catdf['magnitude'] = catdf['magnitude'].astype(float)
#
catdf['origintime'] = pd.to_datetime(catdf['origintime'])
catdf['magnitude'] = catdf['magnitude'].astype(str).replace("None", "0").astype(float)
catdf['magnitude'] = catdf['magnitude'].astype(float)

catdf3 = catdf[catdf['magnitude']>=3]
m3annual = catdf3['origintime'].groupby(catdf3.origintime.dt.to_period("Y")).agg('count')
m3eqcount = catdf3['origintime'].groupby(catdf3.origintime.dt.to_period("M")).agg('count')
df3 = m3eqcount.to_frame()
df3.index = df3.index.to_timestamp()
df3 = df3.resample('MS').sum()



fig, ax1 = plt.subplots()
color = 'black'
ax1.set_xlabel('Year')
ax1.set_ylabel('Earthquakes M3.0+ per month', color=color)
ax1.step(df3.index,df3.origintime, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim([0,110])
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'blue'
ax2.set_ylabel('AOI Arbuckle monthly injection volume (Million bbl/mo)', color=color)  # we already handled the x-label with ax1
ax2.step(arb_sum['Date'],arb_sum['Volume']/1e6, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
#ax2.set_ylim([0,150])
plt.xlim([datetime.date(2009, 1, 1), datetime.datetime.now()])
